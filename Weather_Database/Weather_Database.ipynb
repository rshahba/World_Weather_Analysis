# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create 2,000 sets of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Create an empty list to hold the weather data.
city_data = []

#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | narsaq
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | hanna
# Processing Record 5 of Set 1 | port blair
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | kirovskiy
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 12 of Set 1 | ponta do sol
# City not found. Skipping...
# Processing Record 13 of Set 1 | nantucket
# City not found. Skipping...
# Processing Record 14 of Set 1 | cherskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 16 of Set 1 | leningradskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 18 of Set 1 | ixtapa
# City not found. Skipping...
# Processing Record 19 of Set 1 | fairbanks
# City not found. Skipping...
# Processing Record 20 of Set 1 | hofn
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 22 of Set 1 | garissa
# City not found. Skipping...
# Processing Record 23 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 24 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | tazovskiy
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | sisimiut
# Processing Record 31 of Set 1 | morant bay
# Processing Record 32 of Set 1 | bairiki
# Processing Record 33 of Set 1 | udachnyy
# Processing Record 34 of Set 1 | faanui
# Processing Record 35 of Set 1 | chifeng
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | cayenne
# Processing Record 38 of Set 1 | perelyub
# Processing Record 39 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | hualmay
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | ugoofaaru
# Processing Record 49 of Set 1 | mitu
# Processing Record 50 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | wangqing
# Processing Record 3 of Set 2 | namatanai
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | san cristobal
# Processing Record 8 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 9 of Set 2 | sambava
# Processing Record 10 of Set 2 | yaan
# Processing Record 11 of Set 2 | krasnogvardeyskiy
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | beringovskiy
# Processing Record 14 of Set 2 | oranjestad
# Processing Record 15 of Set 2 | merauke
# Processing Record 16 of Set 2 | barranca de upia
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | morgantown
# Processing Record 19 of Set 2 | constitucion
# Processing Record 20 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | heihe
# Processing Record 28 of Set 2 | luganville
# Processing Record 29 of Set 2 | axim
# Processing Record 30 of Set 2 | general roca
# Processing Record 31 of Set 2 | khandbari
# Processing Record 32 of Set 2 | roald
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | nicoya
# Processing Record 35 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 2 | knysna
# Processing Record 37 of Set 2 | turtkul
# City not found. Skipping...
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | lubango
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | havelock
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | glotovka
# Processing Record 44 of Set 2 | tateyama
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | ostrovnoy
# Processing Record 49 of Set 2 | christchurch
# Processing Record 50 of Set 2 | ushtobe
# Processing Record 1 of Set 3 | barra patuca
# Processing Record 2 of Set 3 | tuatapere
# Processing Record 3 of Set 3 | tiarei
# Processing Record 4 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 3 | businga
# Processing Record 6 of Set 3 | asau
# Processing Record 7 of Set 3 | ciras
# City not found. Skipping...
# Processing Record 8 of Set 3 | guerrero negro
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 3 | guiratinga
# Processing Record 12 of Set 3 | belmonte
# Processing Record 13 of Set 3 | sao filipe
# Processing Record 14 of Set 3 | erenhot
# Processing Record 15 of Set 3 | qaanaaq
# Processing Record 16 of Set 3 | santa lucia
# Processing Record 17 of Set 3 | pacific grove
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | tete
# Processing Record 20 of Set 3 | esperance
# Processing Record 21 of Set 3 | sindgi
# Processing Record 22 of Set 3 | antofagasta
# Processing Record 23 of Set 3 | porto velho
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | kapit
# Processing Record 27 of Set 3 | yuanping
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | tamboril
# Processing Record 30 of Set 3 | bubaque
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | gulshat
# City not found. Skipping...
# Processing Record 34 of Set 3 | kendari
# Processing Record 35 of Set 3 | olafsvik
# Processing Record 36 of Set 3 | lar gerd
# City not found. Skipping...
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | rajpipla
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | mogadishu
# Processing Record 41 of Set 3 | alushta
# Processing Record 42 of Set 3 | vardo
# Processing Record 43 of Set 3 | kuloy
# Processing Record 44 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 3 | trairi
# Processing Record 46 of Set 3 | port augusta
# Processing Record 47 of Set 3 | kloulklubed
# Processing Record 48 of Set 3 | goderich
# Processing Record 49 of Set 3 | bilma
# Processing Record 50 of Set 3 | port hedland
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | nongan
# Processing Record 3 of Set 4 | saiha
# Processing Record 4 of Set 4 | sandwick
# Processing Record 5 of Set 4 | san juan de la maguana
# Processing Record 6 of Set 4 | carnarvon
# Processing Record 7 of Set 4 | vao
# Processing Record 8 of Set 4 | dunedin
# Processing Record 9 of Set 4 | semporna
# Processing Record 10 of Set 4 | carinhanha
# Processing Record 11 of Set 4 | kyra
# Processing Record 12 of Set 4 | landerneau
# Processing Record 13 of Set 4 | ampanihy
# Processing Record 14 of Set 4 | codrington
# Processing Record 15 of Set 4 | mecca
# Processing Record 16 of Set 4 | glenwood springs
# Processing Record 17 of Set 4 | kodiak
# Processing Record 18 of Set 4 | talnakh
# Processing Record 19 of Set 4 | nikki
# Processing Record 20 of Set 4 | plettenberg bay
# Processing Record 21 of Set 4 | pemangkat
# Processing Record 22 of Set 4 | santa cruz de tenerife
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 4 | embrach
# Processing Record 26 of Set 4 | fereydun kenar
# Processing Record 27 of Set 4 | torbay
# Processing Record 28 of Set 4 | opotiki
# Processing Record 29 of Set 4 | awjilah
# Processing Record 30 of Set 4 | aleksandrov gay
# Processing Record 31 of Set 4 | mount gambier
# Processing Record 32 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 4 | manokwari
# Processing Record 34 of Set 4 | goroka
# Processing Record 35 of Set 4 | richards bay
# Processing Record 36 of Set 4 | sloboda
# Processing Record 37 of Set 4 | evensk
# Processing Record 38 of Set 4 | ordu
# Processing Record 39 of Set 4 | luau
# Processing Record 40 of Set 4 | pevek
# Processing Record 41 of Set 4 | ondangwa
# Processing Record 42 of Set 4 | morondava
# Processing Record 43 of Set 4 | komatipoort
# Processing Record 44 of Set 4 | hervey bay
# Processing Record 45 of Set 4 | goundam
# Processing Record 46 of Set 4 | huilong
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | paungde
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 50 of Set 4 | ambilobe
# Processing Record 1 of Set 5 | banga
# Processing Record 2 of Set 5 | miri
# Processing Record 3 of Set 5 | hamilton
# Processing Record 4 of Set 5 | qovlar
# Processing Record 5 of Set 5 | pathein
# Processing Record 6 of Set 5 | saint-augustin
# Processing Record 7 of Set 5 | te anau
# Processing Record 8 of Set 5 | fernandina beach
# Processing Record 9 of Set 5 | salalah
# Processing Record 10 of Set 5 | semnan
# Processing Record 11 of Set 5 | yulara
# Processing Record 12 of Set 5 | margate
# Processing Record 13 of Set 5 | yellowknife
# Processing Record 14 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 5 | saldanha
# Processing Record 16 of Set 5 | grand gaube
# Processing Record 17 of Set 5 | shelburne
# Processing Record 18 of Set 5 | itaituba
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | labuhan
# Processing Record 21 of Set 5 | conselheiro pena
# Processing Record 22 of Set 5 | omsukchan
# Processing Record 23 of Set 5 | kenai
# Processing Record 24 of Set 5 | klaksvik
# Processing Record 25 of Set 5 | paveh
# Processing Record 26 of Set 5 | dehloran
# Processing Record 27 of Set 5 | arlit
# Processing Record 28 of Set 5 | segou
# Processing Record 29 of Set 5 | geraldton
# Processing Record 30 of Set 5 | abu samrah
# Processing Record 31 of Set 5 | tasiilaq
# Processing Record 32 of Set 5 | alice town
# Processing Record 33 of Set 5 | santa cruz
# Processing Record 34 of Set 5 | bayangol
# Processing Record 35 of Set 5 | pafos
# Processing Record 36 of Set 5 | severo-kurilsk
# Processing Record 37 of Set 5 | harlingen
# Processing Record 38 of Set 5 | siyabuswa
# Processing Record 39 of Set 5 | nanortalik
# Processing Record 40 of Set 5 | oliveira dos brejinhos
# Processing Record 41 of Set 5 | carutapera
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | vygonichi
# Processing Record 44 of Set 5 | airai
# Processing Record 45 of Set 5 | berlevag
# Processing Record 46 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 47 of Set 5 | cuenca
# Processing Record 48 of Set 5 | buhe
# Processing Record 49 of Set 5 | jiuquan
# Processing Record 50 of Set 5 | andenes
# Processing Record 1 of Set 6 | riaba
# City not found. Skipping...
# Processing Record 2 of Set 6 | griffith
# Processing Record 3 of Set 6 | havre-saint-pierre
# Processing Record 4 of Set 6 | halifax
# Processing Record 5 of Set 6 | russell
# Processing Record 6 of Set 6 | hithadhoo
# Processing Record 7 of Set 6 | flinders
# Processing Record 8 of Set 6 | haines junction
# Processing Record 9 of Set 6 | benghazi
# Processing Record 10 of Set 6 | tshikapa
# Processing Record 11 of Set 6 | morro bay
# Processing Record 12 of Set 6 | inuvik
# Processing Record 13 of Set 6 | louga
# Processing Record 14 of Set 6 | ancud
# Processing Record 15 of Set 6 | korla
# Processing Record 16 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 6 | gerash
# Processing Record 18 of Set 6 | wanaka
# Processing Record 19 of Set 6 | vysokaya gora
# Processing Record 20 of Set 6 | yablonovo
# Processing Record 21 of Set 6 | batagay-alyta
# Processing Record 22 of Set 6 | zyryanka
# Processing Record 23 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 6 | yar-sale
# Processing Record 25 of Set 6 | khasan
# Processing Record 26 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 6 | karema
# Processing Record 28 of Set 6 | klyuchi
# Processing Record 29 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 6 | roswell
# Processing Record 31 of Set 6 | noumea
# Processing Record 32 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 33 of Set 6 | yining
# Processing Record 34 of Set 6 | meulaboh
# Processing Record 35 of Set 6 | taunggyi
# Processing Record 36 of Set 6 | kaitangata
# Processing Record 37 of Set 6 | praia
# Processing Record 38 of Set 6 | srivardhan
# Processing Record 39 of Set 6 | chapais
# Processing Record 40 of Set 6 | antalaha
# Processing Record 41 of Set 6 | matara
# Processing Record 42 of Set 6 | osa
# Processing Record 43 of Set 6 | tutoia
# Processing Record 44 of Set 6 | morehead
# Processing Record 45 of Set 6 | payo
# Processing Record 46 of Set 6 | vila franca do campo
# Processing Record 47 of Set 6 | paamiut
# Processing Record 48 of Set 6 | markova
# Processing Record 49 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 6 | vestmannaeyjar
# Processing Record 1 of Set 7 | zhezkazgan
# Processing Record 2 of Set 7 | jardim
# Processing Record 3 of Set 7 | zabid
# Processing Record 4 of Set 7 | deputatskiy
# Processing Record 5 of Set 7 | dajal
# Processing Record 6 of Set 7 | lagoa
# Processing Record 7 of Set 7 | yairipok
# Processing Record 8 of Set 7 | yatou
# Processing Record 9 of Set 7 | koumra
# Processing Record 10 of Set 7 | hami
# Processing Record 11 of Set 7 | wuzhou
# Processing Record 12 of Set 7 | tura
# Processing Record 13 of Set 7 | mar del plata
# Processing Record 14 of Set 7 | ronneby
# Processing Record 15 of Set 7 | fortuna
# Processing Record 16 of Set 7 | taoudenni
# Processing Record 17 of Set 7 | poshekhonye
# Processing Record 18 of Set 7 | jalingo
# Processing Record 19 of Set 7 | faridpur
# Processing Record 20 of Set 7 | portland
# Processing Record 21 of Set 7 | baruun-urt
# Processing Record 22 of Set 7 | takoradi
# Processing Record 23 of Set 7 | lipari
# Processing Record 24 of Set 7 | severobaykalsk
# Processing Record 25 of Set 7 | palmer
# Processing Record 26 of Set 7 | lasa
# Processing Record 27 of Set 7 | bonfim
# Processing Record 28 of Set 7 | faya
# Processing Record 29 of Set 7 | boa vista
# Processing Record 30 of Set 7 | mme
# City not found. Skipping...
# Processing Record 31 of Set 7 | ati
# Processing Record 32 of Set 7 | nyimba
# Processing Record 33 of Set 7 | abalak
# Processing Record 34 of Set 7 | maracacume
# Processing Record 35 of Set 7 | adrar
# Processing Record 36 of Set 7 | vestmanna
# Processing Record 37 of Set 7 | coahuayana
# Processing Record 38 of Set 7 | dikson
# Processing Record 39 of Set 7 | leshukonskoye
# Processing Record 40 of Set 7 | manavgat
# Processing Record 41 of Set 7 | waldkirch
# Processing Record 42 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 7 | dzilam gonzalez
# Processing Record 45 of Set 7 | khandyga
# Processing Record 46 of Set 7 | lompoc
# Processing Record 47 of Set 7 | batemans bay
# Processing Record 48 of Set 7 | boundiali
# Processing Record 49 of Set 7 | zhaodong
# Processing Record 50 of Set 7 | broome
# Processing Record 1 of Set 8 | naron
# Processing Record 2 of Set 8 | alofi
# Processing Record 3 of Set 8 | jalu
# Processing Record 4 of Set 8 | acarau
# Processing Record 5 of Set 8 | pangkalanbuun
# Processing Record 6 of Set 8 | itupiranga
# Processing Record 7 of Set 8 | boddam
# Processing Record 8 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 8 | banda aceh
# Processing Record 10 of Set 8 | bengkulu
# Processing Record 11 of Set 8 | nemuro
# Processing Record 12 of Set 8 | harper
# Processing Record 13 of Set 8 | zhigansk
# Processing Record 14 of Set 8 | pokoynoye
# Processing Record 15 of Set 8 | puente nacional
# Processing Record 16 of Set 8 | tautira
# Processing Record 17 of Set 8 | broken hill
# Processing Record 18 of Set 8 | wiwili
# Processing Record 19 of Set 8 | negombo
# Processing Record 20 of Set 8 | the pas
# Processing Record 21 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 8 | prince rupert
# Processing Record 23 of Set 8 | leh
# Processing Record 24 of Set 8 | pasni
# Processing Record 25 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 8 | tiquisio
# Processing Record 27 of Set 8 | bad hersfeld
# Processing Record 28 of Set 8 | aklavik
# Processing Record 29 of Set 8 | blackwater
# Processing Record 30 of Set 8 | norman wells
# Processing Record 31 of Set 8 | nybro
# Processing Record 32 of Set 8 | tahe
# Processing Record 33 of Set 8 | mareeba
# Processing Record 34 of Set 8 | palafrugell
# Processing Record 35 of Set 8 | bonavista
# Processing Record 36 of Set 8 | qafsah
# City not found. Skipping...
# Processing Record 37 of Set 8 | marsh harbour
# Processing Record 38 of Set 8 | shingu
# Processing Record 39 of Set 8 | caldwell
# Processing Record 40 of Set 8 | innisfail
# Processing Record 41 of Set 8 | nizwa
# Processing Record 42 of Set 8 | vanimo
# Processing Record 43 of Set 8 | kiama
# Processing Record 44 of Set 8 | sira
# Processing Record 45 of Set 8 | grindavik
# Processing Record 46 of Set 8 | andra
# Processing Record 47 of Set 8 | boysun
# Processing Record 48 of Set 8 | jijiang
# Processing Record 49 of Set 8 | mumford
# Processing Record 50 of Set 8 | camotan
# Processing Record 1 of Set 9 | tumaco
# Processing Record 2 of Set 9 | havoysund
# Processing Record 3 of Set 9 | gat
# Processing Record 4 of Set 9 | itoman
# Processing Record 5 of Set 9 | satipo
# Processing Record 6 of Set 9 | bara
# Processing Record 7 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 8 of Set 9 | saint-philippe
# Processing Record 9 of Set 9 | shitanjing
# Processing Record 10 of Set 9 | puerto narino
# Processing Record 11 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 9 | buchen
# Processing Record 13 of Set 9 | victoria
# Processing Record 14 of Set 9 | port moresby
# Processing Record 15 of Set 9 | charters towers
# Processing Record 16 of Set 9 | nexo
# Processing Record 17 of Set 9 | yangambi
# Processing Record 18 of Set 9 | grajau
# Processing Record 19 of Set 9 | saint-francois
# Processing Record 20 of Set 9 | buala
# Processing Record 21 of Set 9 | qaqortoq
# Processing Record 22 of Set 9 | culipapa
# City not found. Skipping...
# Processing Record 23 of Set 9 | lufilufi
# Processing Record 24 of Set 9 | playas
# Processing Record 25 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 9 | avera
# Processing Record 27 of Set 9 | chuy
# Processing Record 28 of Set 9 | kavaratti
# Processing Record 29 of Set 9 | rezh
# Processing Record 30 of Set 9 | chekhov
# Processing Record 31 of Set 9 | moose factory
# Processing Record 32 of Set 9 | butaritari
# Processing Record 33 of Set 9 | emerald
# Processing Record 34 of Set 9 | port hardy
# Processing Record 35 of Set 9 | jilotepec
# Processing Record 36 of Set 9 | zhumadian
# Processing Record 37 of Set 9 | suntar
# Processing Record 38 of Set 9 | camopi
# Processing Record 39 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 9 | sindor
# Processing Record 41 of Set 9 | shu
# Processing Record 42 of Set 9 | kuchinarai
# Processing Record 43 of Set 9 | taltal
# Processing Record 44 of Set 9 | isla mujeres
# Processing Record 45 of Set 9 | tulsipur
# Processing Record 46 of Set 9 | husavik
# Processing Record 47 of Set 9 | neuquen
# Processing Record 48 of Set 9 | cidreira
# Processing Record 49 of Set 9 | balkanabat
# Processing Record 50 of Set 9 | obihiro
# Processing Record 1 of Set 10 | vernon
# Processing Record 2 of Set 10 | wanganui
# Processing Record 3 of Set 10 | saint-pierre
# Processing Record 4 of Set 10 | tambura
# Processing Record 5 of Set 10 | waspan
# Processing Record 6 of Set 10 | la orilla
# Processing Record 7 of Set 10 | sur
# Processing Record 8 of Set 10 | kungurtug
# Processing Record 9 of Set 10 | toyooka
# Processing Record 10 of Set 10 | kyshtovka
# Processing Record 11 of Set 10 | malpe
# Processing Record 12 of Set 10 | jackson
# Processing Record 13 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 10 | severodvinsk
# Processing Record 15 of Set 10 | college
# Processing Record 16 of Set 10 | naze
# Processing Record 17 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 10 | sucre
# Processing Record 20 of Set 10 | grand-santi
# Processing Record 21 of Set 10 | sabla
# Processing Record 22 of Set 10 | katsuura
# Processing Record 23 of Set 10 | adre
# Processing Record 24 of Set 10 | sawakin
# Processing Record 25 of Set 10 | rincon
# Processing Record 26 of Set 10 | aranjuez
# Processing Record 27 of Set 10 | marzuq
# Processing Record 28 of Set 10 | kruisfontein
# Processing Record 29 of Set 10 | alpinopolis
# Processing Record 30 of Set 10 | kulhudhuffushi
# Processing Record 31 of Set 10 | zlitan
# Processing Record 32 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 10 | itarema
# Processing Record 34 of Set 10 | les cayes
# Processing Record 35 of Set 10 | hindaun
# Processing Record 36 of Set 10 | sept-iles
# Processing Record 37 of Set 10 | vaasa
# Processing Record 38 of Set 10 | tondano
# Processing Record 39 of Set 10 | ulagan
# Processing Record 40 of Set 10 | victoria point
# Processing Record 41 of Set 10 | aswan
# Processing Record 42 of Set 10 | aljezur
# Processing Record 43 of Set 10 | ahipara
# Processing Record 44 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 10 | padang
# Processing Record 46 of Set 10 | doctor arroyo
# Processing Record 47 of Set 10 | rio gallegos
# Processing Record 48 of Set 10 | port-gentil
# Processing Record 49 of Set 10 | labrea
# Processing Record 50 of Set 10 | westport
# Processing Record 1 of Set 11 | agucadoura
# Processing Record 2 of Set 11 | tanjong sepat
# City not found. Skipping...
# Processing Record 3 of Set 11 | coalinga
# Processing Record 4 of Set 11 | nanchong
# Processing Record 5 of Set 11 | smithers
# Processing Record 6 of Set 11 | watsa
# Processing Record 7 of Set 11 | kushmurun
# Processing Record 8 of Set 11 | kerman
# Processing Record 9 of Set 11 | dzaoudzi
# Processing Record 10 of Set 11 | erzin
# Processing Record 11 of Set 11 | caluquembe
# Processing Record 12 of Set 11 | wasco
# Processing Record 13 of Set 11 | kushima
# Processing Record 14 of Set 11 | touros
# Processing Record 15 of Set 11 | shvartsevskiy
# Processing Record 16 of Set 11 | lata
# Processing Record 17 of Set 11 | mulchen
# Processing Record 18 of Set 11 | whitefish
# Processing Record 19 of Set 11 | tiznit
# Processing Record 20 of Set 11 | keetmanshoop
# Processing Record 21 of Set 11 | acajutla
# Processing Record 22 of Set 11 | atikokan
# Processing Record 23 of Set 11 | sao luiz gonzaga
# Processing Record 24 of Set 11 | mitsamiouli
# Processing Record 25 of Set 11 | yerbogachen
# Processing Record 26 of Set 11 | lavrentiya
# Processing Record 27 of Set 11 | diego de almagro
# Processing Record 28 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 29 of Set 11 | xining
# Processing Record 30 of Set 11 | ketchikan
# Processing Record 31 of Set 11 | kandla
# Processing Record 32 of Set 11 | alta floresta
# Processing Record 33 of Set 11 | bilibino
# Processing Record 34 of Set 11 | hassleholm
# Processing Record 35 of Set 11 | kupang
# Processing Record 36 of Set 11 | bukachacha
# Processing Record 37 of Set 11 | kharan
# Processing Record 38 of Set 11 | zalantun
# Processing Record 39 of Set 11 | lazaro cardenas
# Processing Record 40 of Set 11 | yumen
# Processing Record 41 of Set 11 | vesele
# Processing Record 42 of Set 11 | sao paulo de olivenca
# Processing Record 43 of Set 11 | nome
# Processing Record 44 of Set 11 | sarka ghat
# Processing Record 45 of Set 11 | mayo
# Processing Record 46 of Set 11 | ocampo
# Processing Record 47 of Set 11 | paoua
# Processing Record 48 of Set 11 | krasnoarmeysk
# Processing Record 49 of Set 11 | sorland
# Processing Record 50 of Set 11 | trincomalee
# Processing Record 1 of Set 12 | grants
# Processing Record 2 of Set 12 | saint anthony
# Processing Record 3 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 12 | show low
# Processing Record 5 of Set 12 | wajima
# Processing Record 6 of Set 12 | russellville
# Processing Record 7 of Set 12 | porto novo
# Processing Record 8 of Set 12 | gomoh
# Processing Record 9 of Set 12 | salym
# Processing Record 10 of Set 12 | bayshore gardens
# Processing Record 11 of Set 12 | aksarka
# Processing Record 12 of Set 12 | zhuhai
# Processing Record 13 of Set 12 | puri
# Processing Record 14 of Set 12 | laguna
# Processing Record 15 of Set 12 | rawson
# Processing Record 16 of Set 12 | bulgan
# Processing Record 17 of Set 12 | dao
# Processing Record 18 of Set 12 | la ronge
# Processing Record 19 of Set 12 | kiruna
# Processing Record 20 of Set 12 | bonthe
# Processing Record 21 of Set 12 | pecos
# Processing Record 22 of Set 12 | puro
# Processing Record 23 of Set 12 | sangar
# Processing Record 24 of Set 12 | wattens
# Processing Record 25 of Set 12 | spassk
# Processing Record 26 of Set 12 | viransehir
# Processing Record 27 of Set 12 | dayong
# Processing Record 28 of Set 12 | sistranda
# Processing Record 29 of Set 12 | souillac
# Processing Record 30 of Set 12 | dauphin
# Processing Record 31 of Set 12 | samoded
# Processing Record 32 of Set 12 | namibe
# Processing Record 33 of Set 12 | yagodnoye
# Processing Record 34 of Set 12 | bumba
# Processing Record 35 of Set 12 | camocim
# Processing Record 36 of Set 12 | champerico
# Processing Record 37 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 12 | aleppo
# Processing Record 39 of Set 12 | copiapo
# Processing Record 40 of Set 12 | karratha
# Processing Record 41 of Set 12 | sayat
# Processing Record 42 of Set 12 | radcliff
# Processing Record 43 of Set 12 | kieta
# Processing Record 44 of Set 12 | jacmel
# Processing Record 45 of Set 12 | berezanka
# Processing Record 46 of Set 12 | srednekolymsk
# Processing Record 47 of Set 12 | garachine
# Processing Record 48 of Set 12 | kingaroy
# Processing Record 49 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 12 | hvide sande
# Processing Record 1 of Set 13 | jhargram
# Processing Record 2 of Set 13 | san patricio
# Processing Record 3 of Set 13 | khvalynsk
# Processing Record 4 of Set 13 | barcelos
# Processing Record 5 of Set 13 | newport
# Processing Record 6 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 13 | krasnyy kommunar
# Processing Record 8 of Set 13 | novyy nekouz
# Processing Record 9 of Set 13 | ciumeghiu
# Processing Record 10 of Set 13 | chirongui
# Processing Record 11 of Set 13 | gorey
# Processing Record 12 of Set 13 | yaring
# Processing Record 13 of Set 13 | hue
# Processing Record 14 of Set 13 | cam ranh
# Processing Record 15 of Set 13 | opuwo
# Processing Record 16 of Set 13 | cumpas
# Processing Record 17 of Set 13 | houma
# Processing Record 18 of Set 13 | mapastepec
# Processing Record 19 of Set 13 | sola
# Processing Record 20 of Set 13 | kaliningrad
# Processing Record 21 of Set 13 | medvedka
# Processing Record 22 of Set 13 | piney green
# Processing Record 23 of Set 13 | acapulco
# Processing Record 24 of Set 13 | walvis bay
# Processing Record 25 of Set 13 | afsin
# Processing Record 26 of Set 13 | bay roberts
# Processing Record 27 of Set 13 | freeport
# Processing Record 28 of Set 13 | mehamn
# Processing Record 29 of Set 13 | launceston
# Processing Record 30 of Set 13 | dakar
# Processing Record 31 of Set 13 | sao sebastiao
# Processing Record 32 of Set 13 | pirna
# Processing Record 33 of Set 13 | spencer
# Processing Record 34 of Set 13 | bosaso
# Processing Record 35 of Set 13 | talara
# Processing Record 36 of Set 13 | kuhestan
# City not found. Skipping...
# Processing Record 37 of Set 13 | kosh-agach
# Processing Record 38 of Set 13 | anadyr
# Processing Record 39 of Set 13 | formosa do rio preto
# Processing Record 40 of Set 13 | alyangula
# Processing Record 41 of Set 13 | gilgit
# Processing Record 42 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 13 | stromness
# Processing Record 44 of Set 13 | yuancheng
# Processing Record 45 of Set 13 | ponoka
# Processing Record 46 of Set 13 | emirdag
# Processing Record 47 of Set 13 | lianzhou
# Processing Record 48 of Set 13 | worthington
# Processing Record 49 of Set 13 | wenzhou
# Processing Record 50 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 1 of Set 14 | vila velha
# Processing Record 2 of Set 14 | port-cartier
# Processing Record 3 of Set 14 | panzhihua
# Processing Record 4 of Set 14 | bowen
# Processing Record 5 of Set 14 | mbuguni
# Processing Record 6 of Set 14 | thanh hoa
# Processing Record 7 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 8 of Set 14 | vung tau
# Processing Record 9 of Set 14 | altagracia de orituco
# Processing Record 10 of Set 14 | bathsheba
# Processing Record 11 of Set 14 | jacareacanga
# Processing Record 12 of Set 14 | wawa
# Processing Record 13 of Set 14 | tomakomai
# Processing Record 14 of Set 14 | virginia beach
# Processing Record 15 of Set 14 | caravelas
# Processing Record 16 of Set 14 | ayagoz
# Processing Record 17 of Set 14 | tabas
# Processing Record 18 of Set 14 | wilmington
# Processing Record 19 of Set 14 | rockland
# Processing Record 20 of Set 14 | qeshm
# Processing Record 21 of Set 14 | tessalit
# Processing Record 22 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 14 | san juan
# Processing Record 24 of Set 14 | rudnichnyy
# Processing Record 25 of Set 14 | northam
# Processing Record 26 of Set 14 | fuxin
# Processing Record 27 of Set 14 | elizabeth city
# Processing Record 28 of Set 14 | praia da vitoria
# Processing Record 29 of Set 14 | shentala
# Processing Record 30 of Set 14 | berbera
# Processing Record 31 of Set 14 | seydi
# Processing Record 32 of Set 14 | los llanos de aridane
# Processing Record 33 of Set 14 | olinda
# Processing Record 34 of Set 14 | altamira
# Processing Record 35 of Set 14 | inirida
# Processing Record 36 of Set 14 | sahuaripa
# Processing Record 37 of Set 14 | komsomolskiy
# Processing Record 38 of Set 14 | qinzhou
# Processing Record 39 of Set 14 | seymchan
# Processing Record 40 of Set 14 | burica
# City not found. Skipping...
# Processing Record 41 of Set 14 | bolobo
# Processing Record 42 of Set 14 | limon
# Processing Record 43 of Set 14 | santa rosalia
# Processing Record 44 of Set 14 | dubbo
# Processing Record 45 of Set 14 | basco
# Processing Record 46 of Set 14 | mantua
# Processing Record 47 of Set 14 | atambua
# Processing Record 48 of Set 14 | novobelokatay
# Processing Record 49 of Set 14 | saint george
# Processing Record 50 of Set 14 | yarkovo
# Processing Record 1 of Set 15 | arman
# Processing Record 2 of Set 15 | gracac
# Processing Record 3 of Set 15 | port shepstone
# Processing Record 4 of Set 15 | ust-maya
# Processing Record 5 of Set 15 | helong
# Processing Record 6 of Set 15 | kudahuvadhoo
# Processing Record 7 of Set 15 | yabrud
# Processing Record 8 of Set 15 | waverly
# Processing Record 9 of Set 15 | kidal
# Processing Record 10 of Set 15 | beppu
# Processing Record 11 of Set 15 | taonan
# Processing Record 12 of Set 15 | saint-paul
# Processing Record 13 of Set 15 | nizhniy odes
# Processing Record 14 of Set 15 | kirakira
# Processing Record 15 of Set 15 | road town
# Processing Record 16 of Set 15 | rabo de peixe
# Processing Record 17 of Set 15 | tyrma
# Processing Record 18 of Set 15 | savonlinna
# Processing Record 19 of Set 15 | usinsk
# Processing Record 20 of Set 15 | anloga
# Processing Record 21 of Set 15 | orlik
# Processing Record 22 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 15 | selikhino
# Processing Record 24 of Set 15 | inta
# Processing Record 25 of Set 15 | khorramshahr
# Processing Record 26 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 27 of Set 15 | quatre cocos
# Processing Record 28 of Set 15 | wenling
# Processing Record 29 of Set 15 | uchaly
# Processing Record 30 of Set 15 | ario
# City not found. Skipping...
# Processing Record 31 of Set 15 | dukat
# Processing Record 32 of Set 15 | muswellbrook
# Processing Record 33 of Set 15 | sehithwa
# Processing Record 34 of Set 15 | bambanglipuro
# Processing Record 35 of Set 15 | marawi
# Processing Record 36 of Set 15 | xuddur
# Processing Record 37 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 38 of Set 15 | kailua
# Processing Record 39 of Set 15 | marsabit
# Processing Record 40 of Set 15 | dryden
# Processing Record 41 of Set 15 | puruandiro
# Processing Record 42 of Set 15 | viedma
# Processing Record 43 of Set 15 | biltine
# Processing Record 44 of Set 15 | tual
# Processing Record 45 of Set 15 | san quintin
# Processing Record 46 of Set 15 | livno
# Processing Record 47 of Set 15 | tigzirt
# Processing Record 48 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 15 | santa maria
# Processing Record 50 of Set 15 | puerto maldonado
# Processing Record 1 of Set 16 | prainha
# Processing Record 2 of Set 16 | moussoro
# Processing Record 3 of Set 16 | mezen
# Processing Record 4 of Set 16 | silifke
# Processing Record 5 of Set 16 | buchanan
# Processing Record 6 of Set 16 | zabol
# Processing Record 7 of Set 16 | cabatuan
# Processing Record 8 of Set 16 | bathurst
# Processing Record 9 of Set 16 | lodja
# Processing Record 10 of Set 16 | kisangani
# Processing Record 11 of Set 16 | vanavara
# Processing Record 12 of Set 16 | jiangkou
# Processing Record 13 of Set 16 | huarmey
# Processing Record 14 of Set 16 | baijiantan
# Processing Record 15 of Set 16 | yelniki
# Processing Record 16 of Set 16 | koupela
# Processing Record 17 of Set 16 | athens
# Processing Record 18 of Set 16 | mahajanga
# Processing Record 19 of Set 16 | dhanera
# Processing Record 20 of Set 16 | torrelavega
# Processing Record 21 of Set 16 | yueyang
# Processing Record 22 of Set 16 | zhashkiv
# Processing Record 23 of Set 16 | namtsy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_column = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[city_data_column]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Narsaq      GL  60.9167  -46.0500     53.82        81          93
# 1  Tuktoyaktuk      CA  69.4541 -133.0374     50.00        87          90
# 2       Hobart      AU -42.8794  147.3294     43.27        89          75
# 3        Hanna      CA  51.6334 -111.9018     89.24        15         100
# 4   Port Blair      IN  11.6667   92.7500     81.59        83          99
# 5   Chokurdakh      RU  70.6333  147.9167     45.34        57          51
# 6    Kirovskiy      RU  45.0917  133.5136     69.62        93         100
# 7         Lebu      CL -37.6167  -73.6500     53.83        74          29
# 8        Sitka      US  57.0531 -135.3300     62.49        72          90
# 9    Busselton      AU -33.6500  115.3333     54.10        76         100
#
#    Wind Speed Current Description
# 0        5.08     overcast clouds
# 1        9.22          light rain
# 2        6.91          light rain
# 3       13.69     overcast clouds
# 4       21.05     overcast clouds
# 5        7.81       broken clouds
# 6        1.63     overcast clouds
# 7       19.89    scattered clouds
# 8       10.36     overcast clouds
# 9        7.31     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
